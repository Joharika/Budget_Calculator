# %%
# Budget Calculator
# Initialize a dictionary to hold the budget categories and their amounts
budget = {
    "income": [],
    "expenses": []
}
# Function to add an income
def add_income(amount, description):
    budget['income'].append({"amount": amount, "description": description})
    print(f"Income of ${amount} added: {description}")
# Function to add an expense
def add_expense(amount, description):
    budget['expenses'].append({"amount": amount, "description": description})
    print(f"Expense of ${amount} added: {description}")
# Function to calculate total income
def total_income():
    return sum(item["amount"] for item in budget['income'])
# Function to calculate total expenses
def total_expenses():
    return sum(item["amount"] for item in budget['expenses'])
# Function to calculate the balance
def calculate_balance():
    return total_income() - total_expenses()
# Function to display the budget summary
def display_summary():
    print("\nBudget Summary")
    print("------------------")
    print("Income:")
    for income in budget['income']:
        print(f"  {income['description']}: ${income['amount']}")
    print("Total Income: $", total_income())
    print("\nExpenses:")
    for expense in budget['expenses']:
        print(f"  {expense['description']}: ${expense['amount']}")
    print("Total Expenses: $", total_expenses())
    balance = calculate_balance()
    print("\nBalance: $", balance)
    if balance > 0:
        print(f"Great job! You have a positive balance.Your balance amount is {balance} 😊")
    elif balance == 0:
        print("Your balance is zero. Consider reducing your expenses. 😟")
    else:
        print("Oops! You have a negative balance. Consider reviewing your expenses. 😟")
# Main program loop
while True:
    print("\nBudget Calculator")
    print("1. Add Income")
    print("2. Add Expense")
    print("3. View Summary")
    print("4. Exit")
    choice = input("Choose an option (1-4): ")
    if choice == '1':
        amount = float(input("Enter income amount: "))
        description = input("Enter income description: ")
        add_income(amount, description)
    elif choice == '2':
        amount = float(input("Enter expense amount: "))
        description = input("Enter expense description: ")
        add_expense(amount, description)
    elif choice == '3':
        display_summary()
    elif choice == '4':
        print("Exiting Budget Calculator. Goodbye!")
        break
    else:
        print("Invalid choice. Please choose a valid option.")
# Out:
# Budget Calculator
# 1. Add Income
# 2. Add Expense
# 3. View Summary
# 4. Exit
# Choose an option (1-4): 1
# Enter income amount: 35000
# Enter income description: salary
# Income of $35000.0 added: salary
#
# Budget Calculator
# 1. Add Income
# 2. Add Expense
# 3. View Summary
# 4. Exit
# Choose an option (1-4): 2
# Enter expense amount: 500
# Enter expense description: Groceries
# Expense of $500.0 added: Groceries
#
# Budget Calculator
# 1. Add Income
# 2. Add Expense
# 3. View Summary
# 4. Exit
# Choose an option (1-4): 2
# Enter expense amount: 10000
# Enter expense description: Hostel fee
# Expense of $10000.0 added: Hostel fee
#
# Budget Calculator
# 1. Add Income
# 2. Add Expense
# 3. View Summary
# 4. Exit
# Choose an option (1-4): 2
# Enter expense amount: 2000
# Enter expense description: Clothes
# Expense of $2000.0 added: Clothes
#
# Budget Calculator
# 1. Add Income
# 2. Add Expense
# 3. View Summary
# 4. Exit
# Choose an option (1-4): 3
#
# Budget Summary
# ...
